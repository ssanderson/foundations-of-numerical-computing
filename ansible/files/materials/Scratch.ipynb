# %%
from scipy.misc import face
f = face()

# %%
import matplotlib.pyplot as plt
plt.imshow(f)
plt.show()

# %%
from skimage.data import coins

# %%
c = coins()

# %%
plt.imshow(c)

# %%
# Out:
# (303, 384)
